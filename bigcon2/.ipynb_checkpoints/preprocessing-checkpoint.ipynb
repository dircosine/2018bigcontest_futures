# %%
import pandas as pd
import numpy as np
from math import sqrt
import sqlite3
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import pickle

# %%
con = sqlite3.connect("./movies2.db")

# %%
features = pd.read_sql("SELECT * FROM features", con, index_col=None)
features
# Out:
#       index     id                  title        open  nation  grade  genre  \
# 0         0  00000                   국제시장  2014-12-17       4      0      6
# 1         1  00001                  테이큰 3  2015-01-01       1      1     14
# 2         2  00002              마다가스카의 펭귄  2014-12-31       1      3     13
# 3         3  00003        님아, 그 강을 건너지 마오  2014-11-27       4      3      5
# 4         4  00004                   언브로큰  2015-01-07       1      1     14
# 5         5  00005                    패딩턴  2015-01-07       1      3     17
# 6         6  00006                   기술자들  2014-12-24       4      1     10
# 7         7  00007                    워킹걸  2015-01-07       4      4     17
# 8         8  00008           호빗: 다섯 군대 전투  2014-12-17       1      0     15
# 9         9  00009                타임 패러독스  2015-01-07       1      1      0
# 10       10  00010                  인터스텔라  2014-11-06       1      0      0
# 11       11  00011                아메리칸 셰프  2015-01-07       1      1     17
# 12       12  00012          개를 훔치는 완벽한 방법  2014-12-31       4      3      6
# 13       13  00013      눈의 여왕 2: 트롤의 마법거울  2014-12-24       1      3     13
# 14       14  00014                    상의원  2014-12-24       4      1     11
# 15       15  00015              내일을 위한 시간  2015-01-01       1      0      6
# 16       16  00016                  일곱난쟁이  2014-12-24       1      3     13
# 17       17  00017                 오늘의 연애  2015-01-14       4      1      7
# 18       18  00018                    허삼관  2015-01-14       4      0      6
# 19       19  00021                     마미  2014-12-18       1      1      6
# 20       20  00022     박물관이 살아있다 : 비밀의 무덤  2015-01-14       1      3     15
# 21       21  00030                 유아 낫 유  2015-01-21       1      1      6
# 22       22  00031                더 이퀄라이저  2015-01-28       1      4     14
# 23       23  00032                   쿼바디스  2014-12-10       4      0      5
# 24       24  00033                강남 1970  2015-01-21       4      4     14
# 25       25  00034                    존 윅  2015-01-21       1      4     14
# 26       26  00037              아메리칸 스나이퍼  2015-01-14       1      4     14
# 27       27  00040                    와일드  2015-01-22       1      4      6
# 28       28  00042         그 사람 그 사랑 그 세상  2014-11-20       4      3      5
# 29       29  00051                  빅 히어로  2015-01-21       1      3     13
# ...     ...    ...                    ...         ...     ...    ...    ...
# 1141   1141  11355                    아일라  2018-06-21       1      1      6
# 1142   1142  11356           바르다가 사랑한 얼굴들  2018-06-14       1      3      5
# 1143   1143  11358             빅샤크: 매직체인지  2018-06-27       3      3     13
# 1144   1144  11427      토니스토리2: 고철왕국의 친구들  2018-06-13       1      3     13
# 1145   1145  11428                     마녀  2018-06-27       4      1      9
# 1146   1146  11430      유니콘 원정대: 비밀의 다이어리  2018-06-21       0      3     13
# 1147   1147  11432                  오 루시!  2018-06-28       1      1      7
# 1148   1148  11473        시카리오: 데이 오브 솔다도  2018-06-27       1      1     14
# 1149   1149  11478                 리틀 맨하탄  2018-06-27       1      3      7
# 1150   1150  11538               앤트맨과 와스프  2018-07-04       1      0     14
# 1147      5759       5           11411        1180   6.58
# 1148    116603     212          228377       10923   8.26
# 1149    235499       5           11909        2024   8.66
# 1150   3230279     258         5447070      148224   7.77
# 1151     37585       5           37418        2026   8.12
# 1152     10113       8           10098         768   9.43
# 1153    505189      44         1001952       40844   8.98
# 1154     74284       6          217444        8246   7.65
# 1155   3600098     235         3006106       70271   9.49
# 1156     43041       6           12667        1227   6.63
# 1157     17463       5           17463        1549   9.75
# 1158   4460881     208         6259168       90940   9.35
# 1159    388553      18          670586       15809   9.28
# 1160     77793     158           77792        7888  10.00
# 1161     92580       5          129224        3790   9.57
# 1162   1852610     203          137753        5654   8.88
# 1163   9294016     278        10121576      117542   6.69
# 1164    767212       4         1088118       20530   9.07
# 1165   3464047     257           15613          70   9.03
# 1166     10719       8           12151         548   7.44
# 1167    436075      36          800420       13818   9.52
# 1168   4870449     262         2623048       34670   7.55
# 1169    395748      18          324666        6638   8.62
# 1170   1152528      93          616491       10206   9.83
#
# [1171 rows x 12 columns]

# %%
start_date = '2015-01-07'
end_date = '2018-06-30'
features_20150101_20180630 = features[features['accum_audience'] >= 50000]
features_20150101_20180630 = features_20150101_20180630[features['accum_audience'] <= 5000000]
features_20150101_20180630 = features_20150101_20180630[features['open'] >= start_date]
features_20150101_20180630 = features_20150101_20180630[features['open'] <= end_date]
features_20150101_20180630
# Out:
# C:\Users\Administrator\PycharmProjects\stock\env\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# C:\Users\Administrator\PycharmProjects\stock\env\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# C:\Users\Administrator\PycharmProjects\stock\env\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       index     id                              title        open  nation  \
# 4         4  00004                               언브로큰  2015-01-07       1
# 5         5  00005                                패딩턴  2015-01-07       1
# 7         7  00007                                워킹걸  2015-01-07       4
# 9         9  00009                            타임 패러독스  2015-01-07       1
# 11       11  00011                            아메리칸 셰프  2015-01-07       1
# 17       17  00017                             오늘의 연애  2015-01-14       4
# 18       18  00018                                허삼관  2015-01-14       4
# 20       20  00022                 박물관이 살아있다 : 비밀의 무덤  2015-01-14       1
# 22       22  00031                            더 이퀄라이저  2015-01-28       1
# 24       24  00033                            강남 1970  2015-01-21       4
# 25       25  00034                                존 윅  2015-01-21       1
# 26       26  00037                          아메리칸 스나이퍼  2015-01-14       1
# 27       27  00040                                와일드  2015-01-22       1
# 29       29  00051                              빅 히어로  2015-01-21       1
# 30       30  00078                               위플래쉬  2015-03-12       1
# 33       33  00168        극장판 포켓몬스터 XY : 파괴의 포켓몬과 디안시  2015-01-14       2
# 34       34  00169                            워터 디바이너  2015-01-28       1
# 36       36  00178                           내 심장을 쏴라  2015-01-28       4
# 38       38  00183                              빅 아이즈  2015-01-28       1
# 39       39  00184                             엑스 마키나  2015-01-21       1
# 40       40  00185                                버드맨  2015-03-05       1
# 45       45  00217                            세인트 빈센트  2015-03-05       1
# 46       46  00229                                쎄시봉  2015-02-05       4
# 49       49  00237            최강전사 미니특공대 : 새로운 악당의 습격  2015-02-05       4
# 30        1      6   2592768       6         1588885       56018   9.38
# 33        3     13    302989      15          232345        7467   9.43
# 34        1      6    136275      38          136275        9183   9.22
# 36        1      6    468846     116          387409       20042   9.18
# 38        0      6   1128550      15           85366        5503   8.94
# 39        4      0     78521      16           78521        4066   8.56
# 40        4     17    743123     117          206241       12051   7.99
# 45        0     17    267966      25           86415        6286   9.28
# 46        1      7   1955862     207         1715370       51744   2.95
# 49        3     13     45156       7          155503        4645   9.76
# 50        3     13     52381     215           52381        1855   9.29
# 51        3      2    227214      15          100265        3902   9.33
# 53        1      6    804397     162         1744213       44789   9.00
# 56        3     13    251613       6          503970       13041   9.40
# 57        0     11   3700802     235         3872015       80497   8.45
# 58        3     13    152037      39          298482        7781   8.85
# ...     ...    ...       ...     ...             ...         ...    ...
# 1075      1     12   4833669      35          528007       26817   8.68
# 1077      4     17   1414277     189         1194229       57966   8.59
# 1078      3      1     60561       6           60561        2560   9.42
# 1080      1      5    540596     103          540596       30395   8.23
# 1084      4      9     70570       6          141072       14337   9.39
# 1085      1      3    526073      17          526073       30802   8.39
# 1086      0     14   1039998      52         1385511       55315   8.85
# 1094      3     13     44795       6           64655        2632  10.00
# 1095      0     14    109441       5          109441        5690   8.92
# 1096      3     13    236904     212          122359        5349   9.32
# 1097      1      6    771141     217          771141       43146   6.52
# 1098      3     13     57004       6           57004        3294   9.47
# 1102      3     13     95324       6           95324        3443   9.91
# 1105      3     13    234248      18          388300       12532   9.57
# 1108      4      9    783830     110          528153       26510   8.65
# 1111      4     14   1313326     247         3784602      113314   9.38
# 1116      0      7    111541       6          111541        6141   9.40
# 1117      1      3    147635       7          310956       17089   7.25
# 1120      0     14    307072     212          213980       14838   8.30
# 1125      0     14    651530     139         1335829       55394   8.79
# 1127      1     17   1533822      87         3152872      107944   8.79
# 1130      1     17    240297       5          240297       11926   8.68
# 1131      1      3    177145       5          177145        9319   8.92
# 1135      0      6     32652     108           97850       10272   6.26
# 1138      0      7    639978       7          326083       14861   8.56
# 1139      3     13    302989       1          183421        6845   9.50
# 1140      0      6    143532     172          331438       20353   8.82
# 1143      3     13     83610       6          137645        4856  10.00
# 1145      1      9   2108383     173         3188995       90841   7.82
# 1148      1     14    116603     212          228377       10923   8.26
#
# [585 rows x 12 columns]

# %%
from datetime import datetime,timedelta
from pandas import Series, DataFrame
def convert(s):
    return datetime.strptime(s, '%Y-%m-%d').date()

# %%
cnt = 0

data_ = []
for rows in features_20150101_20180630.iterrows():
    tmp = pd.read_sql("SELECT * FROM "+ "'" +rows[1][1]+ "'", con, index_col=None)
    tmp.drop_duplicates(['date'], inplace=True)
    
    now = convert(rows[1][3])
    if now.weekday() is not 2:
        continue
            
    L=[]
    L=pd.date_range(start = now - timedelta(days=22),end= now + timedelta(days=40))
    df = pd.DataFrame(index=range(63))
    df[:]="0"
    df['date']=L.strftime("%Y-%m-%d")
    df.set_index(df['date'], inplace=True)


    tmp.set_index(tmp['date'], inplace=True)
    tmp=tmp[tmp['date']<=(convert(rows[1][3])+ timedelta(days=40)).strftime("%Y-%m-%d")]
#     tmp=tmp[tmp['date']>=(convert(rows[1][3])- timedelta(days=22)).strftime("%Y-%m-%d")]
    tmp=tmp[tmp['date']>=(convert(rows[1][3])- timedelta(days=22)).strftime("%Y-%m-%d")]


    df_merged = pd.merge(df,tmp, how="outer")
    df_merged.isnull()
    # df_merged

    df_merged[df_merged.isnull()] = 0

#     df_merged['play'] = np.array(pd.to_numeric(df_merged['play'].str.replace(',',''), errors='coerce', downcast='float').tolist()).reshape(-1,1)
    df_merged['audience'] = pd.to_numeric(df_merged['audience'].str.replace(',',''), errors='coerce', downcast='float')
    df_merged['play'] = pd.to_numeric(df_merged['play'].str.replace(',',''), errors='coerce', downcast='float')
#     df_merged['director'] = rows[1][7]
    df_merged=df_merged.fillna(0) # nan값 0으로

#     a_tmp = np.concatenate((df_merged['audience'],[0],df_merged['play'],[0],df_merged['director'],[0])).reshape((3,-1)).T
    a_tmp = np.concatenate((df_merged['audience'],df_merged['play'])).reshape((2,-1)).T

    
#     if len(a_tmp) is not 64:
#         print(tmp)
#         print(df_merged)
#         print(a_tmp)
#         break;
    
    data_.append(a_tmp)
#     dataY_.append([float(rows[1][9])])

#     cnt += 1
#     if cnt>0:
#         break
# Out:
# C:\Users\Administrator\PycharmProjects\stock\env\lib\site-packages\IPython\core\interactiveshell.py:2963: FutureWarning: 'date' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data = np.array(data_)
data.shape
# Out:
# (270, 63, 2)

# %% [markdown]
# ## append D-day

# %%
dday = [i for i in range(-22, 41)]

d_data = []

for d_ in data:
    d_data.append(np.column_stack((d_, dday)))

d_data = np.array(d_data)
np.shape(d_data)
# Out:
# (270, 63, 3)

# %%
np.save('./npy/data_origin.npy', d_data)

# %% [markdown]
# ## for Basic_RNN

# %% [markdown]
# ### split

# %%
# dataX = []
# dataY = []

# size = 40
# input_length = 23

# for s in [range(0,23)]:
#     start = s

#     window = slice(start, start+size)
#     data_window = data[:,window,:]

#     dataX.append(data_window[:,:input_length,:])
#     dataY.append(data_window[:,input_length:,0:1])

# dataX = np.array(dataX)
# dataY = np.array(dataY)

# dataX = dataX.reshape((-1,23,3))
# dataY = dataY.reshape((-1,17,1)).sum(axis=1)

# dataX.shape, dataY.shape
# Out:
# ((23000, 23, 3), (23000, 1))

# %%
size = 40
input_length = 23

# for 물괴
start = 1
window = slice(start, start+size)
data_window = data[:,window,:]

dataX_2 = data_window[:,:input_length,:]
dataY_2 = data_window[:,input_length:,0:1].sum(axis=1)


# # for 너의결혼식, 나를차버린스파이
start = 23
window = slice(start, start+size)
data_window = data[:,window,:]

dataX_23 = data_window[:,:input_length,:]
dataY_23 = data_window[:,input_length:,0:1].sum(axis=1)


# dataX = np.array(dataX)
# dataY = np.array(dataY)

# dataX = dataX.reshape((-1,23,3))
# dataY = dataY.reshape((-1,17,1)).sum(axis=1)

dataX_2.shape, dataY_2.shape
# Out:
# ((1000, 23, 3), (1000, 1))

# %%
for d_ in dataX_2:
    plt.plot(d_[:,0])

# %% [markdown]
# ### scaling

# %%
scalerY_2 = MinMaxScaler(feature_range=(0,1))
scalerY_2 = scalerY_2.fit(dataY_2)
norm_dataY_2 = scalerY_2.transform(dataY_2)

pickle.dump(scalerY_2, open('./scaler/scalerY_2.sav', 'wb'))


scalerX_2 = MinMaxScaler(feature_range=(0,1))
scalerX_2 = scalerX_2.fit(dataX_2.reshape(-1,3))
pickle.dump(scalerX_2, open('./scaler/scalerX_2.sav', 'wb'))
norm_dataX_2 = []
for i in dataX_2:
    norm_dataX_2.append(scalerX_2.transform(i))
norm_dataX_2 = np.array(norm_dataX_2)

norm_dataX_2.shape, norm_dataY_2.shape
# Out:
# ((270, 23, 3), (270, 1))

# %%
np.save('./npy/basic_rnn/dataX_2.npy', norm_dataX_2)
np.save('./npy/basic_rnn/dataY_2.npy', norm_dataY_2)

# %%
scalerY_23 = MinMaxScaler(feature_range=(0,1))
scalerY_23 = scalerY_23.fit(dataY_23)
norm_dataY_23 = scalerY_23.transform(dataY_23)

pickle.dump(scalerY_23, open('./scaler/scalerY_23.sav', 'wb'))



scalerX_23 = MinMaxScaler(feature_range=(0,1))
scalerX_23 = scaler.fit(dataX_23.reshape(-1,3))
pickle.dump(scalerX_23, open('./scaler/scalerX_23.sav', 'wb'))
norm_dataX_23 = []
for i in dataX_23:
    norm_dataX_23.append(scalerX_23.transform(i))
norm_dataX_23 = np.array(norm_dataX_23)

norm_dataX_23.shape, norm_dataY_23.shape
# Out:
# array([[4.19816916e-02, 1.71021107e-01, 0.00000000e+00],
#        [4.64093951e-02, 1.70222476e-01, 4.54545455e-02],
#        [9.33288664e-02, 1.60981175e-01, 9.09090909e-02],
#        [8.32993786e-02, 1.52424415e-01, 1.36363636e-01],
#        [2.78112295e-02, 1.51055334e-01, 1.81818182e-01],
#        [2.68212590e-02, 1.49001711e-01, 2.27272727e-01],
#        [3.61580693e-03, 1.80262407e-02, 2.72727273e-01],
#        [2.94425681e-03, 1.54021677e-02, 3.18181818e-01],
#        [3.53582456e-03, 1.56303480e-02, 3.63636364e-01],
#        [5.29241858e-03, 1.20935539e-02, 4.09090909e-01],
#        [4.67368701e-03, 1.15231033e-02, 4.54545455e-01],
#        [2.07954172e-03, 1.34626355e-02, 5.00000000e-01],
#        [2.26063388e-03, 1.30062750e-02, 5.45454545e-01],
#        [2.05237789e-04, 1.02681118e-03, 5.90909091e-01],
#        [1.16200807e-04, 5.70450656e-04, 6.36363636e-01],
#        [1.34310024e-04, 4.56360525e-04, 6.81818182e-01],
#        [1.69019356e-04, 4.56360525e-04, 7.27272727e-01],
#        [1.90146775e-04, 4.56360525e-04, 7.72727273e-01],
#        [7.69641709e-05, 5.70450656e-04, 8.18181818e-01],
#        [8.14914751e-05, 6.84540787e-04, 8.63636364e-01],
#        [8.90369820e-05, 1.14090131e-04, 9.09090909e-01],
#        [1.20728111e-04, 1.14090131e-04, 9.54545455e-01],
#        [1.13182604e-04, 1.14090131e-04, 1.00000000e+00]])

# %%
np.save('./npy/basic_rnn/dataX_23.npy', norm_dataX_23)
np.save('./npy/basic_rnn/dataY_23.npy', norm_dataY_23)

# %% [markdown]
# ### shuffle

# %%
idx = [i for i in range(23000)]
np.random.shuffle(idx)

shuffled_dataX = []
shuffled_dataY = []

for i in idx:
    shuffled_dataX.append(norm_dataX[i])
    shuffled_dataY.append(norm_dataY[i])
    
shuffled_dataX = np.array(shuffled_dataX)
shuffled_dataY = np.array(shuffled_dataY)

shuffled_dataX.shape, shuffled_dataY.shape

# %%
np.save('./npy/basic_rnn/shuffled_dataX.npy', shuffled_dataX)
np.save('./npy/basic_rnn/shuffled_dataY.npy', shuffled_dataY)
# Out:
# ((23000, 23, 3), (23000, 1))

# %% [markdown]
# ## sampling

# %%
data = np.load('./npy/sampled_data.npy')
data.shape, data.max()
# Out:
# ((1000, 63, 3), 662646.0)

# %% [markdown]
# ## for seq2seq

# %% [markdown]
# ### scaling

# %%
data = d_data
data.shape
# Out:
# (270, 63, 3)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(data.reshape(-1,3)[:,0:1])
pickle.dump(scaler, open('./scaler/scaler_target_seq.sav', 'wb'))

scaler = scaler.fit(data.reshape(-1,3))
pickle.dump(scaler, open('./scaler/scaler_input_seq.sav', 'wb'))
norm_data = []
for i in data:
    norm_data.append(scaler.transform(i))
norm_data = np.array(norm_data)
norm_data.shape
# Out:
# (1000, 63, 3)

# %% [markdown]
# ### split

# %%
encoder_input = []
decoder_target = []

size = 40
input_length = 23

for s in range(0,23):
    start = s

    window = slice(start, start+size)
    data_window = norm_data[:,window,:]

    encoder_input.append(data_window[:,:input_length,:])
    decoder_target.append(data_window[:,input_length:,0:1])

encoder_input = np.array(encoder_input)
decoder_target = np.array(decoder_target)

encoder_input = encoder_input.reshape((-1,23,3))
decoder_target = decoder_target.reshape((-1,17,1))

encoder_input.shape, decoder_target.shape
# Out:
# ((23000, 23, 3), (23000, 17, 1))

# %%
np.save('./npy/seq2seq/encoder_input.npy', encoder_input)
np.save('./npy/seq2seq/decoder_target.npy', decoder_target)

# %% [markdown]
# ### shuffle

# %%
idx = [i for i in range(23000)]
np.random.shuffle(idx)

shuffled_encoder_input = []
shuffled_decoder_target = []

for i in idx:
    shuffled_encoder_input.append(encoder_input[i])
    shuffled_decoder_target.append(decoder_target[i])
    
shuffled_encoder_input = np.array(shuffled_encoder_input)
shuffled_decoder_target = np.array(shuffled_decoder_target)

shuffled_encoder_input.shape, shuffled_decoder_target.shape
# Out:
# ((23000, 23, 3), (23000, 17, 1))

# %%
np.save('./npy/seq2seq/shuffled_encoder_input.npy', shuffled_encoder_input)
np.save('./npy/seq2seq/shuffled_decoder_target.npy', shuffled_decoder_target)
