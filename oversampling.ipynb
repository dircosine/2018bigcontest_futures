# %%
from random import *
 
iteration=50000
Xtmp=[]
Ytmp=[]
#print(len(input_batch), len(target_batch))


for i in range(0, num.shape[0]):
    for j in range(0, int(num[i][0])):
        Xtmp.append(input_batch[i][:][:])
        Ytmp.append(target_batch[i][:])

Xtmp = np.array(Xtmp)
Ytmp = np.array(Ytmp)        
#print(Xtmp.shape, Ytmp.shape)

Xtrain=[]
Ytrain=[]


for i in range(0,iteration):
    if i<len(input_batch):
        Xtrain.append(input_batch[i])
        Ytrain.append(target_batch[i])
    elif i<20000:
        r1 = randint(1, len(Xtmp)-1)
        r2 = randint(1, len(Xtmp)-1)
        Xtrain.append((Xtmp[r1]+Xtmp[r2])/2)
        Ytrain.append((Ytmp[r1]+Ytmp[r2])/2)
    elif i<30000:
        r1 = randint(1, len(Xtmp)-1)
        r2 = randint(1, len(Xtmp)-1)
        r3 = randint(1, len(Xtmp)-1)
        Xtrain.append((Xtmp[r1]+Xtmp[r2]+Xtmp[r3])/3)
        Ytrain.append((Ytmp[r1]+Ytmp[r2]+Ytmp[r3])/3)
    elif i<40000:
        r1 = randint(1, len(Xtmp)-1)
        r2 = randint(1, len(Xtmp)-1)
        r3 = randint(1, len(Xtmp)-1)
        r4 = randint(1, len(Xtmp)-1)
        Xtrain.append((Xtmp[r1]+Xtmp[r2]+Xtmp[r3]+Xtmp[r4])/4)
        Ytrain.append((Ytmp[r1]+Ytmp[r2]+Ytmp[r3]+Ytmp[r4])/4)
    elif i<50000:
        r1 = randint(1, len(Xtmp)-1)
        r2 = randint(1, len(Xtmp)-1)
        r3 = randint(1, len(Xtmp)-1)
        r4 = randint(1, len(Xtmp)-1)
        r5 = randint(1, len(Xtmp)-1)
        Xtrain.append((Xtmp[r1]+Xtmp[r2]+Xtmp[r3]+Xtmp[r4]+Xtmp[r5])/5)
        Ytrain.append((Ytmp[r1]+Ytmp[r2]+Ytmp[r3]+Ytmp[r4]+Ytmp[r5])/5)
#     elif i<5000:
#         r1 = randint(1, len(Xtmp)-1)
#         r2 = randint(1, len(Xtmp)-1)
#         r3 = randint(1, len(Xtmp)-1)
#         r4 = randint(1, len(Xtmp)-1)
#         r5 = randint(1, len(Xtmp)-1)
#         r6 = randint(1, len(Xtmp)-1)
#         Xtrain.append((Xtmp[r1]+Xtmp[r2]+Xtmp[r3]+Xtmp[r4]+Xtmp[r5]+Xtmp[r6])/6)
#         Ytrain.append((Ytmp[r1]+Ytmp[r2]+Ytmp[r3]+Ytmp[r4]+Ytmp[r5]+Ytmp[r6])/6)

Xtrain=np.array(Xtrain)
Ytrain=np.array(Ytrain)
Xtrain.shape, Ytrain.shape
